# %% [markdown]
# <a href="https://colab.research.google.com/github/ROMEROErnest/58010-DSAA/blob/main/longquiz2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Give the formal description of graph G28 = (VG28,EG28)**

# %% [markdown]
# VG28: [E, F, H, I, J, K, M, P]

# %% [markdown]
# EG28:  [E,I] [E,J] [E,K] [F,I] [F,J] [F,K] [H,I] [H,J] [H,K] [M,E] [P,F]

# %% [markdown]
# Draw the adjacency list and matrix representation of the weighted graph.

# %% [markdown]
# **Adjacency List**
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Matrix Representation**
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Implement the graph using Python dictionaries. This must display all the vertices and edges of the graph.

# %%
#EDGES
class graph:
  def __init__(self,gdict=None):
    if gdict is None:
      gdict = {}
    self.gdict = gdict

  def edges(self):
    return self.findedges()

  def findedges(self):
    edgename = []
    for vrtx in self.gdict:
      for nxtvrtx in self.gdict[vrtx]:
        if {nxtvrtx, vrtx} not in edgename:
           edgename.append({vrtx, nxtvrtx})
    return edgename

graph_elements = {
    "E" : ["I","J", "K", "M"],
    "F" : ["I","J", "K", "P"],
    "H" : ["I","J", "K"],
    "I" : ["E","F", "H"],
    "J" : ["E","F", "H"],
    "K" : ["E","F", "H"],
    "M" : ["E"],
    "P" : ["F"]
}
g = graph(graph_elements)
print(g.edges())
# Out:
# [{'E', 'I'}, {'E', 'J'}, {'K', 'E'}, {'E', 'M'}, {'F', 'I'}, {'F', 'J'}, {'F', 'K'}, {'F', 'P'}, {'H', 'I'}, {'H', 'J'}, {'K', 'H'}]

# %%
#VERTICES
class graph:
   def __init__(self,gdict=None):
      if gdict is None:
         gdict = []
      self.gdict = gdict

   def getVertices(self):
      return list(self.gdict.keys())

graph_elements = {
    "E" : ["I","J", "K", "M"],
    "F" : ["I","J", "K", "P"],
    "H" : ["I","J", "K"],
    "I" : ["E","F", "H"],
    "J" : ["E","F", "H"],
    "K" : ["E","F", "H"],
    "M" : ["E"],
    "P" : ["F"]
}
g = graph(graph_elements)
print(g.getVertices())
# Out:
# ['E', 'F', 'H', 'I', 'J', 'K', 'M', 'P']
